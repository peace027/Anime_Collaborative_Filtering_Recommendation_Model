# %%
import numpy as np
import pandas as pd

# %%
anime=pd.read_csv('anime.csv')

# %%
anime.replace('Unknown', pd.NA, inplace=True)

# %%
anime
# Out:
#        MAL_ID                             Name Score  \
# 0           1                     Cowboy Bebop  8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2           6                           Trigun  8.24
# 3           7               Witch Hunter Robin  7.27
# 4           8                   Bouken Ou Beet  6.98
# ...       ...                              ...   ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu   NaN
# 17558   48483                     Mieruko-chan   NaN
# 17559   48488  Higurashi no Naku Koro ni Sotsu   NaN
# 17560   48491      Yama no Susume: Next Summit   NaN
# 17561   48492                    Scarlet Nexus   NaN
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
anime.isnull().sum()
# Out:
# MAL_ID               0
# Name                 0
# Score             5141
# Genres              63
# English name     10565
# Japanese name       48
# Type                37
# Episodes           516
# Aired              309
# Premiered        12817
# Producers         7794
# Licensors        13616
# Studios           7079
# Source            3567
# Duration           555
# Rating             688
# Ranked            1762
# Popularity           0
# Members              0
# Favorites            0
# Watching             0
# Completed            0
# On-Hold              0
# Dropped              0
# Plan to Watch        0
# Score-10           437
# Score-9           3167
# Score-8           1371
# Score-7            503
# Score-6            511
# Score-5            584
# Score-4            977
# Score-3           1307
# Score-2           1597
# Score-1            459
# dtype: int64

# %%
animedf=anime[['MAL_ID','Name','Score','Genres','English name','Japanese name','Type','Episodes','Aired','Source','Duration','Rating','Ranked','Popularity']]
animedf
# Out:
#        MAL_ID                             Name Score  \
# 0           1                     Cowboy Bebop  8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2           6                           Trigun  8.24
# 3           7               Witch Hunter Robin  7.27
# 4           8                   Bouken Ou Beet  6.98
# ...       ...                              ...   ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  <NA>
# 17558   48483                     Mieruko-chan  <NA>
# 17559   48488  Higurashi no Naku Koro ni Sotsu  <NA>
# 17560   48491      Yama no Susume: Next Summit  <NA>
# 17561   48492                    Scarlet Nexus  <NA>
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
anime_with_synopsis=pd.read_csv('anime_with_synopsis.csv')

# %%
anime_with_synopsis
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 16209   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 16210   48483                     Mieruko-chan  Unknown
# 16211   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 16212   48491      Yama no Susume: Next Summit  Unknown
# 16213   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
anime_with_synopsis.replace('Unknown', pd.NA, inplace=True)
anime_with_synopsis.isnull().sum()
# Out:
# MAL_ID          0
# Name            0
# Score        5123
# Genres         63
# sypnopsis       8
# dtype: int64

# %%
animedf=animedf.merge(anime_with_synopsis[['MAL_ID', 'sypnopsis']], on='MAL_ID', how='left')

# %%
animedf.isnull().sum()
# Out:
# MAL_ID               0
# Name                 0
# Score             5141
# Genres              63
# English name     10565
# Japanese name       48
# Type                37
# Episodes           516
# Aired              309
# Source            3567
# Duration           555
# Rating             688
# Ranked            1762
# Popularity           0
# sypnopsis         1356
# dtype: int64

# %%
animedf[animedf['Japanese name'].isna()]
# Out:
#        MAL_ID                                          Name Score  \
# 5750     9387                   Ginga Hyouryuu Vifam Recaps  <NA>
# 10588   30559                                           Why   4.9
# 10618   30668                                   Walking Man  4.17
# 10619   30669                               Why Re-Mix 2002  4.92
# 10684   30859                                 Memory of Red  4.56
# 10686   30861                                  Happy Bogeys  <NA>
# 10942   31424                        Inyouchuu Etsu Special  5.94
# 10974   31501                                Master Blaster  4.38
# 11076   31697                  Witch Village Story Specials  <NA>
# 11292   32253                               Ama Gli Animali  <NA>
# 11543   32813                                          2010  4.86
# 11797   33237                              Romangeun Eobsda  <NA>
# 11837   33312                                   Color Noise  4.56
# ...

# %%
animedf
# Out:
#        MAL_ID                             Name Score  \
# 0           1                     Cowboy Bebop  8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2           6                           Trigun  8.24
# 3           7               Witch Hunter Robin  7.27
# 4           8                   Bouken Ou Beet  6.98
# ...       ...                              ...   ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  <NA>
# 17558   48483                     Mieruko-chan  <NA>
# 17559   48488  Higurashi no Naku Koro ni Sotsu  <NA>
# 17560   48491      Yama no Susume: Next Summit  <NA>
# 17561   48492                    Scarlet Nexus  <NA>
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
from googletrans import Translator

# %%
translator = Translator(service_urls=['translate.google.com'])

# %%
japanese_text = '鷹の爪NEO　予告ムービー'
translation = translator.translate(japanese_text, dest='en')
translation.text
# Out:
# "Hawk's claw NEO notice movie"

# %%
df=animedf.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17562 entries, 0 to 17561
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MAL_ID         17562 non-null  int64
#  1   Name           17562 non-null  object
#  2   Score          12421 non-null  object
#  3   Genres         17499 non-null  object
#  4   English name   6997 non-null   object
#  5   Japanese name  17514 non-null  object
#  6   Type           17525 non-null  object
#  7   Episodes       17046 non-null  object
#  8   Aired          17253 non-null  object
#  9   Source         13995 non-null  object
#  10  Duration       17007 non-null  object
#  11  Rating         16874 non-null  object
#  12  Ranked         15800 non-null  object
#  13  Popularity     17562 non-null  int64
#  14  sypnopsis      16206 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 2.1+ MB

# %%
df['Japanese name'] = df['Japanese name'].fillna(df[df['Japanese name'].isnull()]['Name'].apply(lambda x: print(x) or translator.translate(x, dest='ja').text))
# Out:
# Ginga Hyouryuu Vifam Recaps
# Why
# Walking Man
# Why Re-Mix 2002
# Memory of Red
# Happy Bogeys
# Inyouchuu Etsu Special
# Master Blaster
# Witch Village Story Specials
# Ama Gli Animali
# 2010
# Romangeun Eobsda
# Color Noise
# Aftermath
# Moving Colors
# Xingji Biaoche Wang
# Feng Shu Zhan Jing
# Cyborg 009: Call of Justice 2
# Cyborg 009: Call of Justice 3
# Run & Roll
# Dead World
# Landreaall
# KiyaKiya
# Five Fire Fish
# Aesop Douwa
# Hello Jadoo
# Islay
# Ruby
# To the Moon
# Nuresuke JK Ameyadori Rape
# Soredemo Tsuma wo Aishiteru 2
# Bleach: Gotei 13 Omake
# Te Ke Dong Ji Pian
# Gift nor Art
# Setsugetsuka
# Robot Trains
# Di Ling Qu
# Muteking the Dancing Hero
# Great Pretender
# Orbital Era
# Microphone Soul Spinners: Kotodama Shoujo
# Sol Levante
# Texhnolyze: Revisit
# Rainbow Ruby
# Moldiver Ex
# Tsuki ga Michibiku Isekai Douchuu
# Nu Wushen de Canzhuo Spring Festival Special
# The Sun, Moon and Stars

# %%
df.isnull().sum()
# Out:
# MAL_ID               0
# Name                 0
# Score             5141
# Genres              63
# English name     10565
# Japanese name        0
# Type                37
# Episodes           516
# Aired              309
# Source            3567
# Duration           555
# Rating             688
# Ranked            1762
# Popularity           0
# sypnopsis         1356
# dtype: int64

# %%
df[df['Japanese name'].isna()]
# Out:
# Empty DataFrame
# Columns: [MAL_ID, Name, Score, Genres, English name, Japanese name, Type, Episodes, Aired, Source, Duration, Rating, Ranked, Popularity, sypnopsis]
# Index: []

# %%
animedf[animedf['Japanese name'].isna()]
# Out:
#        MAL_ID                                          Name Score  \
# 5750     9387                   Ginga Hyouryuu Vifam Recaps  <NA>
# 10588   30559                                           Why   4.9
# 10618   30668                                   Walking Man  4.17
# 10619   30669                               Why Re-Mix 2002  4.92
# 10684   30859                                 Memory of Red  4.56
# 10686   30861                                  Happy Bogeys  <NA>
# 10942   31424                        Inyouchuu Etsu Special  5.94
# 10974   31501                                Master Blaster  4.38
# 11076   31697                  Witch Village Story Specials  <NA>
# 11292   32253                               Ama Gli Animali  <NA>
# 11543   32813                                          2010  4.86
# 11797   33237                              Romangeun Eobsda  <NA>
# 11837   33312                                   Color Noise  4.56
# ...

# %%
df_=df[['MAL_ID','English name','Japanese name']].copy()

# %%
df_ = pd.read_csv('df_.csv')
df_0.reset_index(drop=True, inplace=True)
df_0 = pd.DataFrame()
for i in range(13432, 13443):
    df_1.reset_index(drop=True, inplace=True)
    df_1 = df_[(df_['MAL_ID'] < (i + 1) * 1) & (df_['MAL_ID'] >= i * 1)].copy()
    df_1['English name'] = df_1['English name'].fillna(df_1[df_1['English name'].isnull()]['Japanese name'].apply(lambda x: print(x) or translator.translate(x, dest='en').text))
    print("\n\n")
    df_0 = pd.concat([df_0, df_1])
# Out:
# 秘密結社鷹の爪.jp
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[162], line 7
#       5 df_1.reset_index(drop=True, inplace=True)
#       6 df_1 = df_[(df_['MAL_ID'] < (i + 1) * 1) & (df_['MAL_ID'] >= i * 1)].copy()
# ----> 7 df_1['English name'] = df_1['English name'].fillna(df_1[df_1['English name'].isnull()]['Japanese name'].apply(lambda x: print(x) or translator.translate(x, dest='en').text))
#       8 print("\n\n")
#       9 df_0 = pd.concat([df_0, df_1])
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# ...

# %%
df_0.isnull().sum()
# Out:
# MAL_ID           0.0
# English name     0.0
# Japanese name    0.0
# dtype: float64

# %%
df_0
# Out:
# Empty DataFrame
# Columns: [MAL_ID, English name, Japanese name]
# Index: []

# %%
df_.set_index('MAL_ID', inplace=True)
df_0.set_index('MAL_ID', inplace=True)

# Update 'English name' in 'df' with corresponding values from 'df_0' for matching 'MAL_ID'
df_.update(df_0['English name'])

# Reset the index of 'df' back to default
df_.reset_index(inplace=True)

# %%
df_
# Out:
#        MAL_ID                             English name  \
# 0           1                             Cowboy Bebop
# 1           5                   Cowboy Bebop:The Movie
# 2           6                                   Trigun
# 3           7                       Witch Hunter Robin
# 4           8                   Beet the Vandel Buster
# ...       ...                                      ...
# 17557   48481  Qinling God Tree of Grave Robbery Notes
# 17558   48483                 A look child who can see
# 17559   48488          Higurashi:When They Cry – SOTSU
# 17560   48491                Yamano Susume NEXT SUMMIT
# 17561   48492                            SCARLET NEXUS
#
#                           Japanese name
# 0                             カウボーイビバップ
# 1                        カウボーイビバップ 天国の扉
# 2                                 トライガン
# 3      Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                                冒険王ビィト
# ...                                 ...
# ...

# %%
df_.isnull().sum()
# Out:
# MAL_ID           0
# English name     3
# Japanese name    0
# dtype: int64

# %%
df_.to_csv('df_.csv', index=False)

# %%
df.set_index('MAL_ID', inplace=True)

# %%
df
# Out:
#         index                             Name Score  \
# MAL_ID
# 1           0                     Cowboy Bebop  8.78
# 5           1  Cowboy Bebop: Tengoku no Tobira  8.39
# 6           2                           Trigun  8.24
# 7           3               Witch Hunter Robin  7.27
# 8           4                   Bouken Ou Beet  6.98
# ...       ...                              ...   ...
# 48481   17557  Daomu Biji Zhi Qinling Shen Shu  <NA>
# 48483   17558                     Mieruko-chan  <NA>
# 48488   17559  Higurashi no Naku Koro ni Sotsu  <NA>
# 48491   17560      Yama no Susume: Next Summit  <NA>
# 48492   17561                    Scarlet Nexus  <NA>
#
#                                                    Genres  English name  \
# MAL_ID
# 1         Action, Adventure, Comedy, Drama, Sci-Fi, Space           NaN
# 5                   Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop
# 6       Action, Sci-Fi, Adventure, Comedy, Drama, Shounen           NaN
# ...

# %%
df.isnull().sum()
# Out:
# index               0
# Name                0
# Score            5141
# Genres             63
# English name     9876
# Japanese name       0
# Type               37
# Episodes          516
# Aired             309
# Source           3567
# Duration          555
# Rating            688
# Ranked           1762
# Popularity          0
# sypnopsis        1356
# dtype: int64

# %%
df_
# Out:
#                                    English name  \
# MAL_ID
# 1                                  Cowboy Bebop
# 5                        Cowboy Bebop:The Movie
# 6                                        Trigun
# 7                            Witch Hunter Robin
# 8                        Beet the Vandel Buster
# ...                                         ...
# 48481   Qinling God Tree of Grave Robbery Notes
# 48483                  A look child who can see
# 48488           Higurashi:When They Cry – SOTSU
# 48491                 Yamano Susume NEXT SUMMIT
# 48492                             SCARLET NEXUS
#
#                            Japanese name
# MAL_ID
# 1                              カウボーイビバップ
# 5                         カウボーイビバップ 天国の扉
# 6                                  トライガン
# 7       Witch Hunter ROBIN (ウイッチハンターロビン)
# 8                                 冒険王ビィト
# ...                                  ...
# 48481                          盗墓笔记之秦岭神树
# ...

# %%
df_.isnull().sum()
# Out:
# English name     3
# Japanese name    0
# dtype: int64

# %%
# Update 'English name' in 'df' with corresponding values from 'df_0' for matching 'MAL_ID'
df.update(df_['English name'])

# Reset the index of 'df' back to default
df.reset_index(inplace=True)

# %%
df
# Out:
#         index                             Name Score  \
# MAL_ID
# 1           0                     Cowboy Bebop  8.78
# 5           1  Cowboy Bebop: Tengoku no Tobira  8.39
# 6           2                           Trigun  8.24
# 7           3               Witch Hunter Robin  7.27
# 8           4                   Bouken Ou Beet  6.98
# ...       ...                              ...   ...
# 48481   17557  Daomu Biji Zhi Qinling Shen Shu  <NA>
# 48483   17558                     Mieruko-chan  <NA>
# 48488   17559  Higurashi no Naku Koro ni Sotsu  <NA>
# 48491   17560      Yama no Susume: Next Summit  <NA>
# 48492   17561                    Scarlet Nexus  <NA>
#
#                                                    Genres  \
# MAL_ID
# 1         Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 5                   Action, Drama, Mystery, Sci-Fi, Space
# 6       Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 7       Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df[df['English name'].isnull()]
# Out:
# Empty DataFrame
# Columns: [MAL_ID, index, Name, Score, Genres, English name, Japanese name, Type, Episodes, Aired, Source, Duration, Rating, Ranked, Popularity, sypnopsis]
# Index: []

# %%
df.loc[df['Name'] == 'Taka no Tsume NEO Announcement Movie', 'English name'] = "Hawk's claw NEO notice movie"

# %%
df
# Out:
#         index                             Name Score  \
# MAL_ID
# 1           0                     Cowboy Bebop  8.78
# 5           1  Cowboy Bebop: Tengoku no Tobira  8.39
# 6           2                           Trigun  8.24
# 7           3               Witch Hunter Robin  7.27
# 8           4                   Bouken Ou Beet  6.98
# ...       ...                              ...   ...
# 48481   17557  Daomu Biji Zhi Qinling Shen Shu  <NA>
# 48483   17558                     Mieruko-chan  <NA>
# 48488   17559  Higurashi no Naku Koro ni Sotsu  <NA>
# 48491   17560      Yama no Susume: Next Summit  <NA>
# 48492   17561                    Scarlet Nexus  <NA>
#
#                                                    Genres  \
# MAL_ID
# 1         Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 5                   Action, Drama, Mystery, Sci-Fi, Space
# 6       Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 7       Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
df
# Out:
#        MAL_ID  index                             Name Score  \
# 0           1      0                     Cowboy Bebop  8.78
# 1           5      1  Cowboy Bebop: Tengoku no Tobira  8.39
# 2           6      2                           Trigun  8.24
# 3           7      3               Witch Hunter Robin  7.27
# 4           8      4                   Bouken Ou Beet  6.98
# ...       ...    ...                              ...   ...
# 17557   48481  17557  Daomu Biji Zhi Qinling Shen Shu  <NA>
# 17558   48483  17558                     Mieruko-chan  <NA>
# 17559   48488  17559  Higurashi no Naku Koro ni Sotsu  <NA>
# 17560   48491  17560      Yama no Susume: Next Summit  <NA>
# 17561   48492  17561                    Scarlet Nexus  <NA>
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# ...

# %%
df.isnull().sum()
# Out:
# MAL_ID              0
# index               0
# Name                0
# Score            5141
# Genres             63
# English name        0
# Japanese name       0
# Type               37
# Episodes          516
# Aired             309
# Source           3567
# Duration          555
# Rating            688
# Ranked           1762
# Popularity          0
# sypnopsis        1356
# dtype: int64

# %%
df.to_csv('step_1_E&J.csv', index=False)
